# %%
from picarx import Picarx
import time

POWER = 50
SafeDistance = 40   # > 40 safe
DangerDistance = 20 # > 20 && < 40 turn around, 
                    # < 20 backward

def main():
    try:
        px = Picarx()
        # px = Picarx(ultrasonic_pins=['D2','D3']) # tring, echo
       
        while True:
            distance = round(px.ultrasonic.read(), 2)
            print("distance: ",distance)
            if distance >= SafeDistance:
                px.set_dir_servo_angle(0)
                px.forward(POWER)
            elif distance >= DangerDistance:
                px.set_dir_servo_angle(30)
                px.forward(POWER)
                time.sleep(0.1)
            else:
                px.set_dir_servo_angle(-30)
                px.backward(POWER)
                time.sleep(0.5)

    finally:
        px.forward(0)


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 11, in main()
#      10 try:
# ---> 11     px = Picarx()
#      12     # px = Picarx(ultrasonic_pins=['D2','D3']) # tring, echo
#
# File /usr/local/lib/python3.11/dist-packages/picarx-2.0.5-py3.11.egg/picarx/picarx.py:62, in Picarx.__init__(self, servo_pins, motor_pins, grayscale_pins, ultrasonic_pins, config)
#      60     login = getpass.getuser()
# ---> 62 self.config_file: fileDB = fileDB(config, '777', login)
#      64 # --------- Servos Initialization ---------
#
# File /usr/local/lib/python3.11/dist-packages/robot_hat/filedb.py:37, in fileDB.__init__(self, db, mode, owner)
#      36 if self.db:
# ---> 37     self.file_check_create(db, mode, owner)
#      38 else:
#
# File /usr/local/lib/python3.11/dist-packages/robot_hat/filedb.py:71, in fileDB.file_check_create(self, file_path, mode, owner)
#      70 except Exception as e:
# ---> 71     raise e
#
# File /usr/local/lib/python3.11/dist-packages/robot_hat/filedb.py:63, in fileDB.file_check_create(self, file_path, mode, owner)
#      62     sleep(0.001)
# ---> 63 with open(file_path, 'w') as f:
#      64     f.write("# robot-hat config and calibration value of robots\n\n")
#
# PermissionError: [Errno 13] Permission denied: '/opt/picar-x/picar-x.conf'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 34
#      30         px.forward(0)
#      33 if __name__ == "__main__":
# ---> 34     main()
#
# Cell In[7], line 30, in main()
#      27             time.sleep(0.5)
#      29 finally:
# ---> 30     px.forward(0)
#
# UnboundLocalError: cannot access local variable 'px' where it is not associated with a value
